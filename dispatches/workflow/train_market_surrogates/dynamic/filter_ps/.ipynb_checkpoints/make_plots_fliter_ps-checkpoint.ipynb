# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tslearn.utils import to_time_series_dataset
from tslearn.clustering import TimeSeriesKMeans,silhouette_score

# %%
from tslearn_test_filter_ps import TSA64K

# %%
method = 'euclidean'
num_clusters = 20

LMP_data = 'Example_LMP_test.csv'
dispatch_data = 'Example_dispatch_test.csv'

tsa_task = TSA64K(LMP_data,dispatch_data, method)
lmp_array, dispatch_array = tsa_task.read_data()
train_data = tsa_task.transform_data(lmp_array, dispatch_array)

sc,labels = tsa_task.cluster_data(train_data, num_clusters)

# %%
clusters = {}
for i, j in enumerate(labels):
    if j not in clusters:
        clusters[j] = {}
        clusters[j]['lmp'] = []
        clusters[j]['dispatch'] = []
        clusters[j]['lmp'].append(train_data[i][0])
        clusters[j]['dispatch'].append(train_data[i][1])
    else:
        clusters[j]['lmp'].append(train_data[i][0])
        clusters[j]['dispatch'].append(train_data[i][1])

# %%
cluster_results = str(num_clusters) + '_clusters.json'
# print(cluster_results)

with open(cluster_results, 'r') as f:
    cluster_results = json.load(f)
# print(cluster_results)

cen = np.array(cluster_results['model_params']['cluster_centers_'])
time_len = range(24)
# plt.plot(time_len,cen[0][0])
# plt.plot(time_len,cen[1][1])

# %%
def plot_results(num):
    
    font1 = {'family' : 'Times New Roman',
    'weight' : 'normal',
    'size'   : 18,
    }
    f,(ax1,ax2) = plt.subplots(1,2,figsize = ((16,6)))
    for i,j in zip(clusters[num]['lmp'],clusters[num]['dispatch']):
        ax1.plot(time_len,i,'--',c='g', alpha=0.5)
        ax2.plot(time_len,j,'--',c='g', alpha=0.5)
#     ax1.set_ylim(0,100)
    ax1.plot(time_len,cen[num][0], '-',c = 'r')
    ax1.set_ylabel('LMP($/MWh)', font = font1)
    ax1.set_xlabel('Time(h)',font = font1)
    ax2.set_ylabel('Dispatched Power(MW)',font = font1)
    ax2.set_xlabel('Time(h)',font = font1)
    plt.plot(time_len,cen[num][1], '-',c = 'r')
    plt.show()

    return print('The number of days in the cluster_{} is {}'.format(num,len(clusters[num]['lmp'])))

# %%
for i in clusters:
    print('The number of points in cluster_{} is {}'.format(i,len(clusters[i]['lmp'])))
# Out:
# The number of points in cluster_4 is 26
# The number of points in cluster_14 is 8
# The number of points in cluster_12 is 10
# The number of points in cluster_16 is 19
# The number of points in cluster_8 is 11
# The number of points in cluster_6 is 6
# The number of points in cluster_1 is 100
# The number of points in cluster_18 is 21
# The number of points in cluster_15 is 20
# The number of points in cluster_11 is 16
# The number of points in cluster_2 is 13
# The number of points in cluster_5 is 7
# The number of points in cluster_10 is 7
# The number of points in cluster_7 is 22
# The number of points in cluster_3 is 18
# The number of points in cluster_13 is 13
# The number of points in cluster_0 is 4
# The number of points in cluster_9 is 3
# The number of points in cluster_19 is 13
# The number of points in cluster_17 is 4

# %%
for i in range(num_clusters):
    plot_results(i)
# Out:
# The number of days in the cluster_0 is 4
# The number of days in the cluster_1 is 100
# The number of days in the cluster_2 is 13
# The number of days in the cluster_3 is 18
# The number of days in the cluster_4 is 26
# The number of days in the cluster_5 is 7
# The number of days in the cluster_6 is 6
# The number of days in the cluster_7 is 22
# The number of days in the cluster_8 is 11
# The number of days in the cluster_9 is 3
# The number of days in the cluster_10 is 7
# The number of days in the cluster_11 is 16
# The number of days in the cluster_12 is 10
# The number of days in the cluster_13 is 13
# The number of days in the cluster_14 is 8
# The number of days in the cluster_15 is 20
# The number of days in the cluster_16 is 19
# The number of days in the cluster_17 is 4
# The number of days in the cluster_18 is 21
# The number of days in the cluster_19 is 13
