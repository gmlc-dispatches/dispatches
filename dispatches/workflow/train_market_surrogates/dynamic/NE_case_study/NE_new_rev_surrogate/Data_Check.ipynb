# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import pathlib

# %% [markdown]
# ## NE case (10,500)

# %%
# for original data
rev_data = pathlib.Path('NE_revenue.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev = df_rev.iloc[0:48].to_numpy()[:,1]/1000000

# %%
# for predicted data
rev_data = pathlib.Path('NE_predicted_revenue.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev_pred = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev_pred = df_rev_pred.iloc[0:48].to_numpy()[:,1]/1000000

# %%
# calculate the mean error
err = []
for i, j in zip(rev,rev_pred):
    # relative error
    err.append((np.abs(i-j))/i*100)
print(f'The mean error is {np.round(np.mean(err),2)}%')
# Out:
# The mean error is 0.39%

# %%
# for original data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (original) [Million USD] (10,500)')
# Out:
# Text(0.5, 1.0, 'Electricity Revenue (original) [Million USD] (10,500)')

# %%
# for predicted data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev_pred[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (predicted) [Million USD] (10,500)')
# Out:
# Text(0.5, 1.0, 'Electricity Revenue (predicted) [Million USD] (10,500)')

# %%
# plot the revenue at pem ratio = 0.4
x = df_input[36:42]['PEM_indifference_point'].to_numpy()/20
rev_needed = df_rev.iloc[36:42].to_numpy()[:,1]/1000000
rev_pred_needed = df_rev_pred.iloc[36:42].to_numpy()[:,1]/1000000
plt.plot(x, rev_needed, label = 'original')
plt.plot(x, rev_pred_needed, label = 'surrogate')
plt.xlabel('Selling price of Hydrogen [$/kg]')
plt.ylabel('Revenue/M$')
plt.legend()
plt.show()

# %% [markdown]
# ## NE case (10,1000)

# %%
# for original data
rev_data = pathlib.Path('NE_revenue.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev = df_rev.iloc[48:96].to_numpy()[:,1]/1000000

# %%
# for predicted data
rev_data = pathlib.Path('NE_predicted_revenue.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev_pred = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev_pred = df_rev_pred.iloc[48:96].to_numpy()[:,1]/1000000

# %%
# calculate the mean error
err = []
for i, j in zip(rev,rev_pred):
    # relative error
    err.append((np.abs(i-j))/i*100)
print(f'The mean error is {np.round(np.mean(err),2)}%')
# Out:
# The mean error is 0.55%

# %%
# for original data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T,levels = 10)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (original) [Million USD] (10,1000)')
plt.show()

# %%
# for predicted data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev_pred[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T,levels = 10)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (predicted) [Million USD] (10,1000)')
plt.show()

# %%
# plot the revenue at pem ratio = 0.4
x = df_input[84:90]['PEM_indifference_point'].to_numpy()/20
rev_needed = df_rev.iloc[84:90].to_numpy()[:,1]/1000000
rev_pred_needed = df_rev_pred.iloc[84:90].to_numpy()[:,1]/1000000
plt.plot(x, rev_needed, label = 'original')
plt.plot(x, rev_pred_needed, label = 'surrogate')
plt.xlabel('Selling price of Hydrogen [$/kg]')
plt.ylabel('Revenue/M$')
plt.legend()
plt.show()

# %% [markdown]
# ## NE case (15,500)

# %%
# for original data
rev_data = pathlib.Path('NE_revenue.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev = df_rev.iloc[96:144].to_numpy()[:,1]/1000000

# %%
# for predicted data
rev_data = pathlib.Path('NE_predicted_revenue_new.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev_pred = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev_pred = df_rev_pred.iloc[96:144].to_numpy()[:,1]/1000000

# %%
# calculate the mean error
err = []
for i, j in zip(rev,rev_pred):
    # relative error
    err.append((np.abs(i-j))/i*100)
print(f'The mean error is {np.round(np.mean(err),2)}%')
# Out:
# The mean error is 1.5%

# %%
# for original data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (original) [Million USD] (15,500)')
plt.show()

# %%
# for predicted data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev_pred[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (predicted) [Million USD] (15,500)')
plt.show()

# %%
# plot the revenue at pem ratio = 0.4
x = df_input[132:138]['PEM_indifference_point'].to_numpy()/20
rev_needed = df_rev.iloc[132:138].to_numpy()[:,1]/1000000
rev_pred_needed = df_rev_pred.iloc[132:138].to_numpy()[:,1]/1000000
plt.plot(x, rev_needed, label = 'original')
plt.plot(x, rev_pred_needed, label = 'surrogate')
plt.xlabel('Selling price of Hydrogen [$/kg]')
plt.ylabel('Revenue/M$')
plt.legend()
plt.show()

# %% [markdown]
# ## NE case (15,1000)

# %%
# for original data
rev_data = pathlib.Path('NE_revenue.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev = df_rev.iloc[144:192].to_numpy()[:,1]/1000000

# %%
# for predicted data
rev_data = pathlib.Path('NE_predicted_revenue_new.csv')
input_data = pathlib.Path('sweep_parameters_results_NE_whole.h5')
df_rev_pred = pd.read_csv(rev_data)
df_input = pd.read_hdf(input_data)
rev_pred = df_rev_pred.iloc[144:192].to_numpy()[:,1]/1000000

# %%
# calculate the mean error
err = []
for i, j in zip(rev,rev_pred):
    # relative error
    err.append((np.abs(i-j))/i*100)
print(f'The mean error is {np.round(np.mean(err),2)}%')
# Out:
# The mean error is 1.42%

# %%
# for original data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (original) [Million USD] (15,1000)')
plt.show()

# %%
# for predicted data
pem_ratio = np.array([0.05,0.1,0.15,0.2,0.25,0.3,0.4,0.5])
h2_price = np.array([15,20,25,30,35,40])/20
X,Y = np.meshgrid(pem_ratio,h2_price)
rev_contour = np.zeros((len(pem_ratio),len(h2_price)))
c = 0
for p in range(len(pem_ratio)):
    for h in range(len(h2_price)):
        rev_contour[p,h] = rev_pred[c]
        c += 1
# np.shape(rev_contour)
contour = plt.contour(X,Y,rev_contour.T)
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=10)
# plt.scatter(X,Y)
plt.xlabel('Ratio of capacities of PEM and NPP')
plt.ylabel('Selling price of Hydrogen [$/kg]')
plt.title('Electricity Revenue (predicted) [Million USD] (15,1000)')
plt.show()

# %%
# plot the revenue at pem ratio = 0.4
x = df_input[180:186]['PEM_indifference_point'].to_numpy()/20
rev_needed = df_rev.iloc[180:186].to_numpy()[:,1]/1000000
rev_pred_needed = df_rev_pred.iloc[180:186].to_numpy()[:,1]/1000000
plt.plot(x, rev_needed, label = 'original')
plt.plot(x, rev_pred_needed, label = 'surrogate')
plt.xlabel('Selling price of Hydrogen [$/kg]')
plt.ylabel('Revenue/M$')
plt.legend()
plt.show()
